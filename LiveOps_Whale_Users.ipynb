# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
'/content/user_devices1.csv'
'/content/query.csv'
# Out:
# '/content/query.csv'

# %%
df_query =pd.read_csv('/content/drive/MyDrive/query1.csv')
df_rawdata=pd.read_csv('/content/drive/MyDrive/rawdata.csv')

# %%
df_rawdata
# Out:
#                                        gaid
# 0      cb750141-700f-4a47-9443-9209300d7218
# 1      c740d678-f25f-4c29-9654-571a881bf10f
# 2      3edab47f-e878-4958-ba00-c33b2404080a
# 3      66b6e93f-90b2-411c-b0f2-4d4786dea215
# 4      6113448a-c9ff-4617-bc9e-5e49c792658c
# ...                                     ...
# 14087  ffb04950-22a1-4799-a679-161f78cfeeb8
# 14088  6a7f0bf6-15ec-42e3-afa5-03b6437465ad
# 14089  4d6bf460-741e-42b3-8b8a-bae6c414d656
# 14090  ed52679b-a9c5-4aec-8955-4fc198418bc9
# 14091  c9eeefeb-9ba6-b086-5ef8-4437bc759aca
#
# [14092 rows x 1 columns]

# %%
df_query
# Out:
#                                          gaid         device_id  user_id
# 0        c1736c7f-f7c5-476a-90af-bfadb6c66d31  98d71bb650547684   908784
# 1        c1736c7f-f7c5-476a-90af-bfadb6c66d31  98d71bb650547684   910266
# 2        c1736c7f-f7c5-476a-90af-bfadb6c66d31  98d71bb650547684   802050
# 3        c1736c7f-f7c5-476a-90af-bfadb6c66d31  98d71bb650547684    82098
# 4        a3236f1d-1c95-41e2-a0af-1f6f3bbdf39e  ffbdbf5ebb2070f4   924355
# ...                                       ...               ...      ...
# 2884029  520d602f-7435-46fa-a9c9-a5db4bbabbb2  292da02e5c368099   458592
# 2884030  520d602f-7435-46fa-a9c9-a5db4bbabbb2  292da02e5c368099   458601
# 2884031  9ba8e891-66ae-42ed-83c5-afe398dee776  6aab5dfe57231ca2   908803
# 2884032  87c5a091-b439-487b-9da6-d223ae2eacde  29dea83cf25a7b1f   932054
# 2884033  4c0c0ca9-2be3-4c94-b91c-682f185c7d20  8367941e0caaeb0a   791790
#
# [2884034 rows x 3 columns]

# %%
df_rawdata.head()

# %%
print(df_rawdata.columns)
print(df_query1.columns)

# %%
df_merged = df_rawdata.merge(df_query[['gaid', 'user_id']], on='gaid', how='left')
df_merged
# Out:
#                                        gaid    user_id
# 0      cb750141-700f-4a47-9443-9209300d7218  1280098.0
# 1      c740d678-f25f-4c29-9654-571a881bf10f  1131961.0
# 2      c740d678-f25f-4c29-9654-571a881bf10f  1701160.0
# 3      c740d678-f25f-4c29-9654-571a881bf10f  1131961.0
# 4      c740d678-f25f-4c29-9654-571a881bf10f  1701160.0
# ...                                     ...        ...
# 63228  ed52679b-a9c5-4aec-8955-4fc198418bc9  2250741.0
# 63229  ed52679b-a9c5-4aec-8955-4fc198418bc9  1948634.0
# 63230  ed52679b-a9c5-4aec-8955-4fc198418bc9  2250741.0
# 63231  ed52679b-a9c5-4aec-8955-4fc198418bc9  1948634.0
# 63232  c9eeefeb-9ba6-b086-5ef8-4437bc759aca        NaN
#
# [63233 rows x 2 columns]

# %%
len(df_rawdata)

# %%
len(df_merged)

# %%
df_query.head()

# %%
df_merged

# %%
len(df_query)

# %%
df_query['gaid'].value_counts().reset_index().query("gaid > 1")

# %%
print("Unique GAIDs in df_rawdata:", df_rawdata['gaid'].nunique())
print("Unique GAIDs in df_query1:", df_query['gaid'].nunique())
print("Total GAID Matches:", df_rawdata['gaid'].isin(df_query['gaid']).sum())

# %%
df_query_unique = df_query.drop_duplicates(subset=['gaid'], keep='first')
df_result = df_rawdata.merge(df_query_unique[['gaid', 'user_id']], on='gaid', how='left')
df_result
# Out:
#                                        gaid    user_id
# 0      cb750141-700f-4a47-9443-9209300d7218  1280098.0
# 1      c740d678-f25f-4c29-9654-571a881bf10f  1131961.0
# 2      3edab47f-e878-4958-ba00-c33b2404080a  2128823.0
# 3      66b6e93f-90b2-411c-b0f2-4d4786dea215   363844.0
# 4      6113448a-c9ff-4617-bc9e-5e49c792658c  2151161.0
# ...                                     ...        ...
# 14087  ffb04950-22a1-4799-a679-161f78cfeeb8  2130215.0
# 14088  6a7f0bf6-15ec-42e3-afa5-03b6437465ad  2060786.0
# 14089  4d6bf460-741e-42b3-8b8a-bae6c414d656  1131469.0
# 14090  ed52679b-a9c5-4aec-8955-4fc198418bc9  2250741.0
# 14091  c9eeefeb-9ba6-b086-5ef8-4437bc759aca        NaN
#
# [14092 rows x 2 columns]

# %%
df_result.to_csv("df_result2.csv", index=False)

# %%
num_nan = df_result['user_id'].isna().sum()
print(f"Number of NaN values in 'user_id' column: {num_nan}")
# Out:
# Number of NaN values in 'user_id' column: 1563
